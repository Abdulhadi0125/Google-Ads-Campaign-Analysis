# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Google Ads Analysis.csv")

# %%
df.head()
# Out:
#   Reporting starts           Campaign name Objective  Reach  Impressions  \
# 0       2025-05-03        05_HEAD_Thiet ke  Messages    311          319
# 1       2025-05-03    08_HEAD_Daily Flower  Messages    430          563
# 2       2025-05-03        05_HEAD_Thiet ke  Messages   2866         3273
# 3       2025-05-03  13_HEAD_Campaign_08.03  Messages   2492         3200
# 4       2025-05-03          04_HEAD_Breezy  Messages   1414         1578
#
#    Frequency  Amount spent (VND)  CTR (link click-through rate)  \
# 0   1.025723               25232                       0.313480
# 1   1.309302               51080                       0.177620
# 2   1.142010              199299                       0.488848
# 3   1.284109              254354                       0.093750
# 4   1.115983               60138                       0.823828
#
#    CPC (All) (VND)  CPM (cost per 1,000 impressions) (VND)  \
# 0      1146.909091                             79097.17868
# ...

# %%
df_duplicated_rows = df[df.duplicated()]

# %%
df_duplicated_rows
# Out:
#      Reporting starts            Campaign name   Objective  Reach  \
# 672        2025-04-17     07_HEAD_Hoa cat canh  Engagement      0
# 754        2025-04-15  01_HEAD_Embrace of Tana    Messages      0
# 763        2025-04-15      10_HEAD_Lan Ho diep    Messages      0
# 768        2025-04-15     07_HEAD_Hoa cat canh  Engagement      0
# 772        2025-04-15     07_HEAD_Hoa cat canh  Engagement      0
# 827        2025-04-14     07_HEAD_Hoa cat canh  Engagement      0
# 873        2025-04-13         05_HEAD_Thiet ke    Messages      0
# 934        2025-04-12         05_HEAD_Thiet ke    Messages      0
# 1017       2025-04-10     07_HEAD_Hoa cat canh  Engagement      0
#
#       Impressions  Frequency  Amount spent (VND)  \
# 672             0        0.0                   0
# 754             0        0.0                   0
# 763             0        0.0                   0
# 768             0        0.0                   0
# 772             0        0.0                   0
# ...

# %%
df.shape
# Out:
# (1313, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Reporting starts                        1313 non-null   object
#  1   Campaign name                           1313 non-null   object
#  2   Objective                               1313 non-null   object
#  3   Reach                                   1313 non-null   int64
#  4   Impressions                             1313 non-null   int64
#  5   Frequency                               1313 non-null   float64
#  6   Amount spent (VND)                      1313 non-null   int64
#  7   CTR (link click-through rate)           1313 non-null   float64
#  8   CPC (All) (VND)                         1313 non-null   float64
#  9   CPM (cost per 1,000 impressions) (VND)  1313 non-null   float64
# ...

# %%
df.describe()
# Out:
#               Reach   Impressions    Frequency  Amount spent (VND)  \
# count   1313.000000   1313.000000  1313.000000         1313.000000
# mean     701.206398    803.849962     1.080708        44455.952780
# std      955.881942   1058.847817     0.273838        45351.189728
# min        0.000000      0.000000     0.000000            0.000000
# 25%      168.000000    185.000000     1.050847        13695.000000
# 50%      458.000000    515.000000     1.100640        29790.000000
# 75%      885.000000   1043.000000     1.188648        60067.000000
# max    11716.000000  12508.000000     2.351648       305989.000000
#
#        CTR (link click-through rate)  CPC (All) (VND)  \
# count                    1313.000000      1313.000000
# mean                        0.710179       968.160897
# std                         0.803222      1006.820921
# min                         0.000000         0.000000
# 25%                         0.125628       515.254237
# ...

# %%
df_cleaned = df.drop_duplicates()

# %%
df_cleaned.shape
# Out:
# (1304, 17)

# %%
df_cleaned.isnull().sum()
# Out:
# Reporting starts                          0
# Campaign name                             0
# Objective                                 0
# Reach                                     0
# Impressions                               0
# Frequency                                 0
# Amount spent (VND)                        0
# CTR (link click-through rate)             0
# CPC (All) (VND)                           0
# CPM (cost per 1,000 impressions) (VND)    0
# Cost per 1,000 people reached (VND)       0
# Conversions                               0
# Conversion values                         0
# Cost per conversion                       0
# Post comments                             0
# Link clicks                               0
# Messaging Conversations Started           0
# dtype: int64

# %%
df_cleaned['Reporting starts'] = pd.to_datetime(df_cleaned['Reporting starts'])
# Out:
# /tmp/ipython-input-39-3072761504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Reporting starts'] = pd.to_datetime(df_cleaned['Reporting starts'])

# %%
df_cleaned.head()
# Out:
#   Reporting starts           Campaign name Objective  Reach  Impressions  \
# 0       2025-05-03        05_HEAD_Thiet ke  Messages    311          319
# 1       2025-05-03    08_HEAD_Daily Flower  Messages    430          563
# 2       2025-05-03        05_HEAD_Thiet ke  Messages   2866         3273
# 3       2025-05-03  13_HEAD_Campaign_08.03  Messages   2492         3200
# 4       2025-05-03          04_HEAD_Breezy  Messages   1414         1578
#
#    Frequency  Amount spent (VND)  CTR (link click-through rate)  \
# 0   1.025723               25232                       0.313480
# 1   1.309302               51080                       0.177620
# 2   1.142010              199299                       0.488848
# 3   1.284109              254354                       0.093750
# 4   1.115983               60138                       0.823828
#
#    CPC (All) (VND)  CPM (cost per 1,000 impressions) (VND)  \
# 0      1146.909091                             79097.17868
# ...

# %%
df_cleaned.columns = df_cleaned.columns.str.lower().str.replace(' ', '_')

# %%
df_cleaned.head()
# Out:
#   reporting_starts           campaign_name objective  reach  impressions  \
# 0       2025-05-03        05_HEAD_Thiet ke  Messages    311          319
# 1       2025-05-03    08_HEAD_Daily Flower  Messages    430          563
# 2       2025-05-03        05_HEAD_Thiet ke  Messages   2866         3273
# 3       2025-05-03  13_HEAD_Campaign_08.03  Messages   2492         3200
# 4       2025-05-03          04_HEAD_Breezy  Messages   1414         1578
#
#    frequency  amount_spent_(vnd)  ctr_(link_click-through_rate)  \
# 0   1.025723               25232                       0.313480
# 1   1.309302               51080                       0.177620
# 2   1.142010              199299                       0.488848
# 3   1.284109              254354                       0.093750
# 4   1.115983               60138                       0.823828
#
#    cpc_(all)_(vnd)  cpm_(cost_per_1,000_impressions)_(vnd)  \
# 0      1146.909091                             79097.17868
# ...

# %%
df_cleaned.to_csv('cleaned_campaign_data.csv', index=False)
